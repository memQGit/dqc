# %% [markdown]
# # memQ Distributed Quantum Compiler & Scheduler Demo
# In this notebook, we provide a walkthrough of two key parts of the memQ xDQC software stack - compilation and scheduling. By the end of this notebook, the user will be able to crfeate compiled programs and gate schedules for custom distributed quantum networks.

# %% [markdown]
# ## Part 1: Defining the inputs
# ### Section A: Creating your quantum network
# xDQC uses a JSON representation of the quantum network as an input. This file defines:
# - Number of QPU's in the network
# - Number of data (computation) qubits and communication qubits in each QPU
# - Local connectivity of each QPU
# - Inter-QPU connectivity
# To streamline the process of defining these specifications, we provide a simple GUI to allow users to easily and visually describe any arbitrary quantum network. To generate your network, visit the link [TODO: INSERT LINK](google.com), then download the JSON file and move it into your working directory. In this tutorial, we will be using a pre-generated JSON representation of a quantum network as shown below:
#
# ![demo_network.png](demo/demo_network.png)
